# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
def movingsum(inputlst,k):
  lst = []
  while(len(inputlst)>= k):
    newlst = inputlst[0:k]
    lst.append(sum(newlst)/k)
    popelement = inputlst.pop(0)
  return lst

# %%
import numpy as np

# %%
inputlst = [3, 5, 7, 2, 8, 10, 11, 65, 72, 81, 99, 100, 150]

# %%
final_mat = np.mat(movingsum(inputlst,3))

# %%
final_mat
# Out:
# matrix([[  5.        ,   4.66666667,   5.66666667,   6.66666667,
#            9.66666667,  28.66666667,  49.33333333,  72.66666667,
#           84.        ,  93.33333333, 116.33333333]])
